# %%
import pandas as pd
mountains = pd.read_csv('Mountains.csv')

# %%
mountains
# Out:
#      Rank                                  Mountain  Height (m)  Height (ft)  \
# 0       1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 1       2                K2 / Qogir / Godwin Austen        8611        28251
# 2       3                             Kangchenjunga        8586        28169
# 3       4                                    Lhotse        8516        27940
# 4       5                                    Makalu        8485        27838
# 5       6                                   Cho Oyu        8188        26864
# 6       7                              Dhaulagiri I        8167        26795
# 7       8                                   Manaslu        8163        26781
# 8       9                              Nanga Parbat        8126        26660
# 9      10                               Annapurna I        8091        26545
# 10     11           Gasherbrum I / Hidden Peak / K5        8080        26509
# ...

# %%
parent_mountains = mountains['Parent mountain']
parent_mountains
# Out:
# 0                     NaN
# 1           Mount Everest
# 2           Mount Everest
# 3           Mount Everest
# 4           Mount Everest
# 5           Mount Everest
# 6                      K2
# 7                 Cho Oyu
# 8              Dhaulagiri
# 9                 Cho Oyu
# 10                     K2
# 11           Gasherbrum I
# 12           Gasherbrum I
# 13                Cho Oyu
# 14                Cho Oyu
# 15          Gasherbrum II
# 16            Annapurna I
# 17         Gasherbrum III
# 18                Manaslu
# 19                     K2
# 20                Manaslu
# 21                 Lhotse
# 22          Distaghil Sar
# 23           Gasherbrum I
# 24             Dhaulagiri
# 25                 Makalu
# 26          Distaghil Sar
# 27        Khunyang Chhish
# 28        Khunyang Chhish
# 29          Kangchenjunga
#               ...
# 88              Skil Brum
# 89              Chogolisa
# 90                Cho Oyu
# 91         Skil Brum (K2)
# 92          Mount Everest
# ...

# %%
mountains = mountains['Parent mountain'].value_counts()
mountains
# Out:
# Mount Everest         9
# Gasherbrum I          8
# Kangchenjunga         7
# Cho Oyu               7
# K2                    5
# Distaghil Sar         5
# Shisha Pangma         4
# Dhaulagiri            4
# Kamet                 3
# Khunyang Chhish       3
# Teram Kangri I        3
# Manaslu               3
# Dhaulagiri IV         3
# Batura Sar            3
# Nanda Devi            2
# Kongur Tagh           2
# Annapurna I           2
# Saltoro Kangri        2
# Saser Kangri I        2
# Lhotse                2
# Gangkhar Puensum      2
# Chogolisa             2
# Gangkar Puensum       2
# Noshaq                2
# Skil Brum             2
# Malubiting            2
# Gasherbrum III        1
# Masherbrum            1
# Trivor                1
# Shispare              1
# Annapurna             1
# Yukshin Gardan Sar    1
# Tirich Mir            1
# Churen Himal          1
# Muztagh Ata           1
# Ghent Kangri          1
# Momhil Sar            1
# Ismail Samani Peak    1
# ...

# %%
mountains[mountains > 3].to_frame('count')
# Out:
#                count
# Mount Everest      9
# Gasherbrum I       8
# Kangchenjunga      7
# Cho Oyu            7
# K2                 5
# Distaghil Sar      5
# Shisha Pangma      4
# Dhaulagiri         4
