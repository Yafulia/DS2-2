# %%
import pandas as pd

# %%
data = pd.read_csv( 'Mountains.csv', delimiter = ',' )
data.head(10)
# Out:
#    Rank                                  Mountain  Height (m)  Height (ft)  \
# 0     1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 1     2                K2 / Qogir / Godwin Austen        8611        28251
# 2     3                             Kangchenjunga        8586        28169
# 3     4                                    Lhotse        8516        27940
# 4     5                                    Makalu        8485        27838
# 5     6                                   Cho Oyu        8188        26864
# 6     7                              Dhaulagiri I        8167        26795
# 7     8                                   Manaslu        8163        26781
# 8     9                              Nanga Parbat        8126        26660
# 9    10                               Annapurna I        8091        26545
#
#    Prominence (m)                   Range              Coordinates  \
# 0            8848     Mahalangur Himalaya  27°59′17″N 86°55′31″E﻿
# ...

# %%
data1 = data.groupby('Parent mountain').count()

# %%
data1
# Out:
#                     Rank  Mountain  Height (m)  Height (ft)  Prominence (m)  \
# Parent mountain
# Annapurna              1         1           1            1               1
# Annapurna I            2         2           2            2               2
# Annapurna III          1         1           1            1               1
# Batura Sar             3         3           3            3               3
# Cho Oyu                7         7           7            7               7
# Chogolisa              2         2           2            2               2
# Churen Himal           1         1           1            1               1
# Dhaulagiri             4         4           4            4               4
# Dhaulagiri II          1         1           1            1               1
# Dhaulagiri IV          3         3           3            3               3
# Distaghil Sar          5         5           5            5               5
# ...

# %%
data2 = data1.loc[:, ['Mountain']]

# %%
data2
# Out:
#                     Mountain
# Parent mountain
# Annapurna                  1
# Annapurna I                2
# Annapurna III              1
# Batura Sar                 3
# Cho Oyu                    7
# Chogolisa                  2
# Churen Himal               1
# Dhaulagiri                 4
# Dhaulagiri II              1
# Dhaulagiri IV              3
# Distaghil Sar              5
# Gangkar Puensum            2
# Gangkhar Puensum           2
# Gasherbrum I               8
# Gasherbrum II              1
# Gasherbrum III             1
# Ghent Kangri               1
# Ismail Samani Peak         1
# K2                         5
# Kamet                      3
# Kangchenjunga              7
# Kanjut Sar                 1
# Khunyang Chhish            3
# Kongur Tagh                2
# Kula Kangri                1
# Labuche Kang               1
# Lhotse                     2
# Makalu                     1
# Malubiting                 2
# Manaslu                    3
# ...

# %%
data2.query('Mountain > 3')
# Out:
#                  Mountain
# Parent mountain
# Cho Oyu                 7
# Dhaulagiri              4
# Distaghil Sar           5
# Gasherbrum I            8
# K2                      5
# Kangchenjunga           7
# Mount Everest           9
# Shisha Pangma           4
